# %% [markdown]
# <a href="https://colab.research.google.com/github/youreyesarecameras-dot/maxnum/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Please enter number 1 "))
num2 = int(input("Please enter number 2 "))
num3 = int(input("Please enter number 3 "))

if num1 > num2 and num3:
 print("The biggest number is", num1)

if num2 > num1 and num3:
 print("The biggest number is", num2)

if num3 > num1 and num2:
 print("The biggest number is", num3)
# Out:
# Please enter number 1 12
# Please enter number 2 56
# Please enter number 3 43
# The biggest number is 56
# The biggest number is 43
